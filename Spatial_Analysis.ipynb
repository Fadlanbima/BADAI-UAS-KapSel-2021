# %% [markdown]
# <a href="https://colab.research.google.com/github/Fadlanbima/BADAI_UAS_KapSel/blob/main/Spatial_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install unidecode twython tweepy beautifulsoup4 tika
# Out:
# ...
#      |████████████████████████████████| 235 kB 5.5 MB/s
# ...
#   Created wheel for tika: filename=tika-1.24-py3-none-any.whl size=32891 sha256=f236d222da2c96009dddac7436cdb86a961961fa9883fb1a533dc34a0dfff06a
#   Stored in directory: /root/.cache/pip/wheels/ec/2b/38/58ff05467a742e32f67f5d0de048fa046e764e2fbb25ac93f3
# Successfully built tika
# ...

# %%
import warnings; warnings.simplefilter('ignore')
import tweepy, json, nltk, urllib.request, requests
from urllib.request import Request, urlopen
from twython import TwythonStreamer
from bs4 import BeautifulSoup as bs

# %%
Ck = 'tXIjpNtsebTPQXPeI0srjbmtJ' # consumer_key
Cs = 'WEJtNxUHC4nvOG9Je3iZs3PRBqMAqGHfsGYrkyQngCC2w0VvU5' # consumer_secret
At = '1346046289922805760-1LRd2BXqBQ8ncIQB4991tyiQUpioMU' # access_token
As = 'nCF5jP6cxF4WAgvC2cgOKsruXBUVd7hFZY5WA2gsCSJyO' # access_secret

# %%
def connect(Ck, Cs, At, As):
    auth = tweepy.auth.OAuthHandler(Ck, Cs)
    auth.set_access_token(At, As)
    api = tweepy.API(auth)
    usr_ = api.verify_credentials()
    print('Welcome "{}" you are now connected to twitter server'.format(usr_.name))
    return api

# %%
api = connect(Ck, Cs, At, As)
# Out:
# Welcome "Tikaa" you are now connected to twitter server

# %%
import pandas as pd

# %%
#mendapatkan tweet wilayah aceh
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "5.548290,95.323753,200km", 500  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space.append([tweet.text, tweet.retweet_count])

spacedf = pd.DataFrame(data=space, columns=['tweet','retweet_count'])
sdf = spacedf.assign(City = 'Banda Aceh', Province = 'Aceh')
sdf
# Out:
#                                                tweet  ...  Province
# 0  @infobdg Sebagai org yg pernah kerja di RS, te...  ...      Aceh
# 1  @jigeumjana I dah la nak cepat, that day hujan...  ...      Aceh
# 2  Hujan Angin Kencang, Pohon Tumbang Timpa Dua R...  ...      Aceh
# 3  "Laporan BPBA, terdapat bibit siklon tropis 94...  ...      Aceh
# 4  Angin Kencang dan Hujan Deras Tumbangkan Pohon...  ...      Aceh
# 5  #BeritaBireuen\nKalak BPBD Bireuen, Afwadi BA ...  ...      Aceh
#
# [6 rows x 4 columns]

# %%
#mendapatkan tweet wilayah medan
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "3.597031,98.678513,200km", 500  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space1 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space1.append([tweet.text, tweet.retweet_count])

spacedf1 = pd.DataFrame(data=space1, columns=['tweet','retweet_count'])
sdf1 = spacedf1.assign(City = 'Medan', Province = 'North Sumatra')
sdf1
# Out:
#                                                 tweet  ...       Province
# 0   Aku risau je bila dengar bunyi zink ni. Confus...  ...  North Sumatra
# 1   @ufamofaza iya mi. angin kuat, hujan nonstop. ...  ...  North Sumatra
# 2   @infobdg Sebagai org yg pernah kerja di RS, te...  ...  North Sumatra
# 3   Peringatan Dini Cuaca Banten tgl 9 Desember 20...  ...  North Sumatra
# 4   @chitaglorya__ Dari kemarin kak chita hujan an...  ...  North Sumatra
# 5   @chitaglorya__ Pandeglang banten hujan angin s...  ...  North Sumatra
# 6   @chitaglorya__ Hujan kak chit\nAku jg baru plg...  ...  North Sumatra
# 7   Tak Ada Angin Tak Ada Hujan, Putra Ahok Ini Ng...  ...  North Sumatra
# 8   Coba yg ngerti cuaca ko gw bingung ya anyer bi...  ...  North Sumatra
# 9   Dari pagi belum kena nasi,, order gofood eeh h...  ...  North Sumatra
# 10  UPDATE Peringatan Dini Cuaca Banten tgl 6 Dese...  ...  North Sumatra
# 11  Peringatan Dini Cuaca Banten tgl 6 Desember 20...  ...  North Sumatra
# ...

# %%
#mendapatkan tweet wilayah pekan baru
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "0.533505,98.678513,200km", 500  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space2 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space2.append([tweet.text, tweet.retweet_count])

spacedf2 = pd.DataFrame(data=space2, columns=['tweet','retweet_count'])
sdf2 = spacedf2.assign(City = 'Pekan Baru', Province = 'Riau')
sdf2
# Out:
#                                                tweet  ...  Province
# 0  Gak ada hujan gak ada angin gak ada ganti pin ...  ...      Riau
# 1  Kembali dirundung bencana, segera pulih Indone...  ...      Riau
# 2  @chitaglorya__ Hujan kak chit\nAku jg baru plg...  ...      Riau
# 3  BMKG Perkirakan Hujan Lebat Disertai Angin Ter...  ...      Riau
# 4  Kamar gw emang mantep bgt, di saat kamar lain ...  ...      Riau
#
# [5 rows x 4 columns]

# %%
#mendapatkan tweet wilayah padang
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-0.952470,100.361820,200km", 500  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space3 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space3.append([tweet.text, tweet.retweet_count])

spacedf3 = pd.DataFrame(data=space3, columns=['tweet','retweet_count'])
sdf3 = spacedf3.assign(City = 'Padang', Province = 'West Sumatra')
sdf3
# Out:
#                                                 tweet  ...      Province
# 0   Minggu 12 Desember, Hujan Lebat Disertai Petir...  ...  West Sumatra
# 1                             https://t.co/f0bn08PtNZ  ...  West Sumatra
# 2   BMKG: Hotspot Riau Nihil dan Cuaca Berpotensi ...  ...  West Sumatra
# 3   Ini nih akibat dari gak bisa kalau udah hujan ...  ...  West Sumatra
# 4   Malam Ini Riau Diguyur Hujan Tidak Merata, BMK...  ...  West Sumatra
# 5   Gani³ Fanny² hujan, badai, angin ribut. Lala³ ...  ...  West Sumatra
# 6   Gak ada hujan gak ada angin gak ada ganti pin ...  ...  West Sumatra
# 7   Kembali dirundung bencana, segera pulih Indone...  ...  West Sumatra
# 8   @chitaglorya__ Lagi musim hujan kak... Udah se...  ...  West Sumatra
# 9   Hotspot Nihil, Hujan Lebat Disertai Angin Kenc...  ...  West Sumatra
# 10  Kirain gak lebat udh sengaja nerobos hujan gk ...  ...  West Sumatra
# 11  Pekanbaru diguyur hujan deras dan angin kencan...  ...  West Sumatra
# ...

# %%
#mendapatkan tweet wilayah Tanjung Pinang
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "0.920945,104.444997,200km", 500  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space4 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space4.append([tweet.text, tweet.retweet_count])

spacedf4 = pd.DataFrame(data=space4, columns=['tweet','retweet_count'])
sdf4 = spacedf4.assign(City = 'Tanjung Pinang', Province = 'The Riau Islands')
sdf4
# Out:
#                                                 tweet  ...          Province
# 0   Mendung tebal\nAngin kencang\nSuara gemuruh\nB...  ...  The Riau Islands
# 1   BMKG: Hotspot Riau Nihil dan Cuaca Berpotensi ...  ...  The Riau Islands
# 2   iolss dah nikah. @ainshahirah__  dia macam kee...  ...  The Riau Islands
# 3   Ini nih akibat dari gak bisa kalau udah hujan ...  ...  The Riau Islands
# 4   Malam Ini Riau Diguyur Hujan Tidak Merata, BMK...  ...  The Riau Islands
# 5   Naik kapal ferry rutin karimun-batam dan ombak...  ...  The Riau Islands
# 6   Gani³ Fanny² hujan, badai, angin ribut. Lala³ ...  ...  The Riau Islands
# 7   Angin datang kasih kabar\nDia bilang se su san...  ...  The Riau Islands
# 8   Kat luar tak hujan, takde awan tapi angin kuat...  ...  The Riau Islands
# 9   @rstation_id Apa yg salah? Ini kan beliau lagi...  ...  The Riau Islands
# 10  terkadang mendung datang seiring dengan awan, ...  ...  The Riau Islands
# ...

# %%
#mendapatkan tweet wilayah bengkulu
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-3.791670,102.263600,200km", 500  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space5 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space5.append([tweet.text, tweet.retweet_count])

spacedf5 = pd.DataFrame(data=space5, columns=['tweet','retweet_count'])
sdf5 = spacedf5.assign(City = 'Bengkulu', Province = 'Bengkulu')
sdf5
# Out:
#                                                 tweet  ...  Province
# 0   Hujan ditambah angin kenceng, kondisi yg pas u...  ...  Bengkulu
# 1   Mau muntah saya, musim hujan badan jadi masuk ...  ...  Bengkulu
# 2   Meskipun pake jas hujan, kalo udah ujan+angin ...  ...  Bengkulu
# 3   Ujan deres, angin, anak main hujan²an.\nTampu ...  ...  Bengkulu
# 4    @alfianyan_ hujan badai\nangin ribut\nhalilintar  ...  Bengkulu
# 5   Combo sekali ini h-2 vaksin scaling gigi, habi...  ...  Bengkulu
# 6   @puding_coklatt @Telkomsel Disini malah cerah ...  ...  Bengkulu
# 7                Pagi2 hujan angin. Coba hujan bigwin  ...  Bengkulu
# 8                         @yournangel Hujan angin kak  ...  Bengkulu
# 9   @chitaglorya__ Lagi musim hujan kak... Udah se...  ...  Bengkulu
# 10  Hujan badai, angin ribut, tetep beli nasi pece...  ...  Bengkulu
# 11        udh hujan angin dingin bgt gila lo ya Bogor  ...  Bengkulu
# 12  @Aditction gaada angin, gaada hujan tbtb kok m...  ...  Bengkulu
# ...

# %%
#mendapatkan tweet wilayah jambi
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-1.609972,103.607254,200km", 500  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space6 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space6.append([tweet.text, tweet.retweet_count])

spacedf6 = pd.DataFrame(data=space6, columns=['tweet','retweet_count'])
sdf6 = spacedf6.assign(City = 'Jambi', Province = 'Jambi')
sdf6
# Out:
#                                                tweet  ...  Province
# 0  Minggu 12 Desember, Hujan Lebat Disertai Petir...  ...     Jambi
# 1                            https://t.co/f0bn08PtNZ  ...     Jambi
# 2  Hujan ditambah angin kenceng, kondisi yg pas u...  ...     Jambi
# 3  @chitaglorya__ Lagi musim hujan kak... Udah se...  ...     Jambi
# 4  Kemunculan Halo (lingkaran yang\nmengelilingi ...  ...     Jambi
# 5  @di_cbn halo min.. mau laporan plus minta tolo...  ...     Jambi
# 6  @convomf Baru melek, gara-gara hujan angin, ke...  ...     Jambi
#
# [7 rows x 4 columns]

# %%
#mendapatkan tweet wilayah lampung
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-5.429750,105.262270,80km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space7 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space7.append([tweet.text, tweet.retweet_count])

spacedf7 = pd.DataFrame(data=space7, columns=['tweet','retweet_count'])
sdf7 = spacedf7.assign(City = 'Bandar Lampung', Province = 'Lampung')
sdf7
# Out:
#                                                 tweet  ...  Province
# 0                Hujan yang deres, angin yang kenceng  ...   Lampung
# 1   Mau muntah saya, musim hujan badan jadi masuk ...  ...   Lampung
# 2   Meskipun pake jas hujan, kalo udah ujan+angin ...  ...   Lampung
# 3   Ujan deres, angin, anak main hujan²an.\nTampu ...  ...   Lampung
# 4    @alfianyan_ hujan badai\nangin ribut\nhalilintar  ...   Lampung
# 5   Combo sekali ini h-2 vaksin scaling gigi, habi...  ...   Lampung
# 6   Hujan tahap 2 yg td tahap 1 derasnya hampir sa...  ...   Lampung
# 7   tadi siang panas banget, sekarang malem hujan ...  ...   Lampung
# 8   @puding_coklatt @Telkomsel Disini malah cerah ...  ...   Lampung
# 9   Hujan badai, angin ribut, tetep beli nasi pece...  ...   Lampung
# 10  Lagian orang2 ke pantai hujan angin gini biar ...  ...   Lampung
# 11  Hujan deras disertai angin kencang wilayah ser...  ...   Lampung
# 12                         @KuroBoy14 iya hujan angin  ...   Lampung
# ...

# %%
#mendapatkan tweet wilayah Pangkal pinang
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-2.133333,106.116669,200km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space8 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space8.append([tweet.text, tweet.retweet_count])

spacedf8 = pd.DataFrame(data=space8, columns=['tweet','retweet_count'])
sdf8 = spacedf8.assign(City = 'Pangkal Pinang', Province = 'Bangka Belitung Islands')
sdf8
# Out:
#                                                 tweet  ...                 Province
# 0   Minggu 12 Desember, Hujan Lebat Disertai Petir...  ...  Bangka Belitung Islands
# 1                             https://t.co/f0bn08PtNZ  ...  Bangka Belitung Islands
# 2   Hujan ditambah angin kenceng, kondisi yg pas u...  ...  Bangka Belitung Islands
# 3       @fkgirrls_ Hujan lebat tambah angin jd dingin  ...  Bangka Belitung Islands
# 4                Pagi2 hujan angin. Coba hujan bigwin  ...  Bangka Belitung Islands
# 5                         @yournangel Hujan angin kak  ...  Bangka Belitung Islands
# 6   @chitaglorya__ Lagi musim hujan kak... Udah se...  ...  Bangka Belitung Islands
# 7         udh hujan angin dingin bgt gila lo ya Bogor  ...  Bangka Belitung Islands
# 8   2 Hari ini Belitung Hujan🌧🌧 Guys..kayaknya Bes...  ...  Bangka Belitung Islands
# 9              @QANR__ Masuk angin dah itu hujan lagi  ...  Bangka Belitung Islands
# ...

# %%
#mendapatkan tweet wilayah Palembang
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-2.990934,104.756554,200km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space9 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space9.append([tweet.text, tweet.retweet_count])

spacedf9 = pd.DataFrame(data=space9, columns=['tweet','retweet_count'])
sdf9 = spacedf9.assign(City = 'Palembang', Province = 'South Sumatra')
sdf9
# Out:
#                                                tweet  ...       Province
# 0  Minggu 12 Desember, Hujan Lebat Disertai Petir...  ...  South Sumatra
# 1                            https://t.co/f0bn08PtNZ  ...  South Sumatra
# 2  Hujan ditambah angin kenceng, kondisi yg pas u...  ...  South Sumatra
# 3               Pagi2 hujan angin. Coba hujan bigwin  ...  South Sumatra
# 4                        @yournangel Hujan angin kak  ...  South Sumatra
# 5  @chitaglorya__ Lagi musim hujan kak... Udah se...  ...  South Sumatra
# 6        udh hujan angin dingin bgt gila lo ya Bogor  ...  South Sumatra
# 7  @Aditction gaada angin, gaada hujan tbtb kok m...  ...  South Sumatra
# 8  @di_cbn halo min.. mau laporan plus minta tolo...  ...  South Sumatra
# 9  @convomf Baru melek, gara-gara hujan angin, ke...  ...  South Sumatra
#
# [10 rows x 4 columns]

# %%
sumatera=pd.concat([sdf,sdf1,sdf2,sdf3,sdf4,sdf5,sdf6,sdf7,sdf8,sdf9]).reset_index(drop=True)
sumatera.to_json('/content/sumatera.json', orient='records')

# %%
#mendapatkan tweet wilayah serang
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-6.120000,106.150276,25km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space10 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space10.append([tweet.text, tweet.retweet_count])

spacedf10 = pd.DataFrame(data=space10, columns=['tweet','retweet_count'])
sdf10 = spacedf10.assign(City = 'Serang', Province = 'Banten')
sdf10
# Out:
#                                                  tweet  ...  Province
# 0    Makassar Kembali Diguyur Hujan, BMKG: Waspada ...  ...    Banten
# 1    14.15 #LalinSonora\n\nTol Cipularang, KM 59, h...  ...    Banten
# 2    Tol Cipularang, KM 59, hujan deras disertai an...  ...    Banten
# 3    UPDATE PERINGATAN DINI CUACA JABODETABEK\nDura...  ...    Banten
# 4    Makassar Kembali Diguyur Hujan, BMKG: Waspada ...  ...    Banten
# ..                                                 ...  ...       ...
# 195  Catatan hari ini:\nDi Depok hujan angin. Emang...  ...    Banten
# 196  Pulang pulang hujan badai, baru berasa takut o...  ...    Banten
# 197  Paling takut hujan campur angin kenceng dan ki...  ...    Banten
# 198  Keren bgt diriku sanggup melewati hujan angin ...  ...    Banten
# 199  18.20 #InfoSonora\n\nHujan angin di kawasan Ma...  ...    Banten
#
# [200 rows x 4 columns]

# %%
#mendapatkan tweet wilayah Jakarta
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-6.250490,106.909180,25km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space11 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space11.append([tweet.text, tweet.retweet_count])

spacedf11 = pd.DataFrame(data=space11, columns=['tweet','retweet_count'])
sdf11 = spacedf11.assign(City = 'Jakarta', Province = 'Jakarta')
sdf11
# Out:
#                                                  tweet  ...  Province
# 0    Makassar Kembali Diguyur Hujan, BMKG: Waspada ...  ...   Jakarta
# 1    14.15 #LalinSonora\n\nTol Cipularang, KM 59, h...  ...   Jakarta
# 2    Tol Cipularang, KM 59, hujan deras disertai an...  ...   Jakarta
# 3    UPDATE PERINGATAN DINI CUACA JABODETABEK\nDura...  ...   Jakarta
# 4                                      Hujan angin T_T  ...   Jakarta
# ..                                                 ...  ...       ...
# 195  Pada sore hari berpeluang turun hujan dengan i...  ...   Jakarta
# 196  Dikutip dari laman https://t.co/JaVxvemz08, hu...  ...   Jakarta
# 197  BMKG: Waspada Hujan, Petir, da Angin di Jakart...  ...   Jakarta
# 198  "Berpotensi terjadi hujan Sedang-Lebat yang da...  ...   Jakarta
# 199  Badan Penanggulangan Bencana Daerah (BPBD) Pro...  ...   Jakarta
#
# [200 rows x 4 columns]

# %%
#mendapatkan tweet wilayah bandung
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-6.917464,107.619125,25km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space12 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space12.append([tweet.text, tweet.retweet_count])

spacedf12 = pd.DataFrame(data=space12, columns=['tweet','retweet_count'])
sdf12 = spacedf12.assign(City = 'Bandung', Province = 'West Java')
sdf12
# Out:
#                                                 tweet  ...   Province
# 0                               hujan angin euy serem  ...  West Java
# 1   13.13: RT @FRMNBCHTR: Hujan deras angin guludu...  ...  West Java
# 2   @PRFMnews @infobdg Hujan deras angin guludug d...  ...  West Java
# 3   beresin setrikaan yg udh menggunung, begitu be...  ...  West Java
# 4   [Min @PRFMnews izin melaporkan jalan cipamokol...  ...  West Java
# ..                                                ...  ...        ...
# 84  @sukahujanhujan Hujan kakk nanti masuk angin k...  ...  West Java
# 85  @billymaximopp Tiris teu Joy? Hawa angin bekas...  ...  West Java
# 86  @bibliophire Haha hujan badai angin ribut 😂gak...  ...  West Java
# 87        @aameleean Pantesan hujan angin dodar gelap  ...  West Java
# 88  Berteduh dari runtuh\nkita bangkit dan tumbuh ...  ...  West Java
#
# [89 rows x 4 columns]

# %%
#mendapatkan tweet wilayah yogya
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-7.802640,110.365051,25km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space13 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space13.append([tweet.text, tweet.retweet_count])

spacedf13 = pd.DataFrame(data=space13, columns=['tweet','retweet_count'])
sdf13 = spacedf13.assign(City = 'Yogyakarta', Province = 'Special Region of Yogyakarta')
sdf13
# Out:
#                                                 tweet  ...                      Province
# 0   dia terus menerus terkena hujan, angin, terik ...  ...  Special Region of Yogyakarta
# 1   Mini soccer diwarnai hujan..\nMalam minggu seh...  ...  Special Region of Yogyakarta
# 2   @pln_123 min.. tolong Ds.Jodag RT 04, jalur uj...  ...  Special Region of Yogyakarta
# 3   Cari angin dulu...tapi hujan deres...😅 https:/...  ...  Special Region of Yogyakarta
# 4   ga ada angin ga ada hujan tiba2 pamer usus gor...  ...  Special Region of Yogyakarta
# ..                                                ...  ...                           ...
# 68  aku suka vibe hari ini, rumah gak ribut, ga ad...  ...  Special Region of Yogyakarta
# 69  Tiba tiba gelap, angin menyusul, mungkin hujan...  ...  Special Region of Yogyakarta
# 70  Hujan badai angin ribut halilintar https://t.c...  ...  Special Region of Yogyakarta
# ...

# %%
#mendapatkan tweet wilayah semarang
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-7.005145,110.438126,25km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space14 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space14.append([tweet.text, tweet.retweet_count])

spacedf14 = pd.DataFrame(data=space14, columns=['tweet','retweet_count'])
sdf14 = spacedf14.assign(City = 'Semarang', Province = 'Central Java')
sdf14
# Out:
#                                                 tweet  ...      Province
# 0   @eskrimmatcha_ hujan badai, angin ribut gass t...  ...  Central Java
# 1   @BTS_twtt_MINPD Kalau aku memiliki musim hujan...  ...  Central Java
# 2                             hujan badai angin ribut  ...  Central Java
# 3   terngiang-ngiang\n"hujan badai angin ribut hal...  ...  Central Java
# 4   Hai #SahabatTangguh akhir tahun hingga awal bu...  ...  Central Java
# 5   @ohmybeautybank Terkena badai angin hujan,helm...  ...  Central Java
# 6   @apriniam Yappp bener karena semalem hujan ang...  ...  Central Java
# 7                        anjeng tiba tiba hujan angin  ...  Central Java
# 8    @BossTemlen S3 ilmu pengendali angin hujan badai  ...  Central Java
# 9                            oke serem. hujan angin ⛈  ...  Central Java
# 10  @rdi971 #dbdshpw\nKalau menurut saya cucian bi...  ...  Central Java
# 11  BMKG Waspada Potensi Hujan Deras Disertai Angi...  ...  Central Java
# ...

# %%
#mendapatkan tweet wilayah surabaya
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-7.257472,112.752090,25km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space15 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space15.append([tweet.text, tweet.retweet_count])

spacedf15 = pd.DataFrame(data=space15, columns=['tweet','retweet_count'])
sdf15 = spacedf15.assign(City = 'Surabaya', Province = 'East Java')
sdf15
# Out:
#                                                 tweet  ...   Province
# 0               @e100ss Wonokromo hujan deras + angin  ...  East Java
# 1                @e100ss Gayungan hujan deras + angin  ...  East Java
# 2                                   Anjir hujan angin  ...  East Java
# 3   Ijin meneruskan postingan saya sebelumnya.\n\n...  ...  East Java
# 4   @e100ss 16.06: Wilayah Ketintang Selatan HUJAN...  ...  East Java
# ..                                                ...  ...        ...
# 91  @tapikamunggk Sidoarjo terpantau hujan ringan ...  ...  East Java
# 92  @zarryhendrik Hujan badai. Angin. Ribut halili...  ...  East Java
# 93  @PorosHalangID salatiga sejam yg lalu ada angi...  ...  East Java
# 94  Kota Angin dingin banget, udah hujan aja dari ...  ...  East Java
# 95  @DiajengLrst Sering kak.. Gak ada angin gak ad...  ...  East Java
#
# [96 rows x 4 columns]

# %%
jawa=pd.concat([sdf10,sdf11,sdf12,sdf13,sdf14,sdf15]).reset_index(drop=True)
jawa.to_json('/content/jawa.json', orient='records')

# %%
#mendapatkan tweet wilayah pontianak
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "0.000000,109.333336,100km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space16 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space16.append([tweet.text, tweet.retweet_count])

spacedf16 = pd.DataFrame(data=space16, columns=['tweet','retweet_count'])
sdf16 = spacedf16.assign(City = 'Pontianak', Province = 'West Kalimantan')
sdf16
# Out:
#                                                tweet  ...         Province
# 0  Apa karna renang pas hujan, keramas kelamaan, ...  ...  West Kalimantan
# 1  @istrinya_ubet Lagi hujan ya mak.. Aku malah s...  ...  West Kalimantan
# 2      @fkgirrls_ Hujan lebat tambah angin jd dingin  ...  West Kalimantan
# 3  angin nya was wus...malming kyk nya hujan..bua...  ...  West Kalimantan
#
# [4 rows x 4 columns]

# %%
#mendapatkan tweet wilayah samarinda
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "	-0.502106,117.153709,100km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space17 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space17.append([tweet.text, tweet.retweet_count])

spacedf17 = pd.DataFrame(data=space17, columns=['tweet','retweet_count'])
sdf17 = spacedf17.assign(City = 'Samarinda', Province = 'East Kalimantan')
sdf17
# Out:
#                                                tweet  ...         Province
# 0       angin kencang+hujan deras, mana masih diluar  ...  East Kalimantan
# 1          kena hujan angin pagi-pagi langsung demam  ...  East Kalimantan
# 2  Walaupun hujan badai, angin topan Guru matemat...  ...  East Kalimantan
# 3  Kawasan Balikpapan Tengah dan sekitarnya terpa...  ...  East Kalimantan
#
# [4 rows x 4 columns]

# %%
#mendapatkan tweet wilayah banjarmasin
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-3.316694,114.590111,100km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space18 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space18.append([tweet.text, tweet.retweet_count])

spacedf18 = pd.DataFrame(data=space18, columns=['tweet','retweet_count'])
sdf18 = spacedf18.assign(City = 'Banjarmasin', Province = 'South Kalimantan')
sdf18
# Out:
#                                                 tweet  ...          Province
# 0   Dingin bnget🥶 ujan nya gk berenti² berrrr\nDis...  ...  South Kalimantan
# 1   Malam itu, saat anak dan istri om sudah tidur....  ...  South Kalimantan
# 2   Orang zaman dulu hebat2 ya, dipenjara sekaligu...  ...  South Kalimantan
# 3   Aku bukannya tidak menyukai hujan, \nHanya tid...  ...  South Kalimantan
# 4   @missufe Hai 🙋‍♀️ makji.di sini dingin hbs huj...  ...  South Kalimantan
# 5   semalam air pasang hujan deras + angin banter ...  ...  South Kalimantan
# 6   Stay safe sebanjaran hujan deras + banyu pasan...  ...  South Kalimantan
# 7        Deras banget hujan + angin 😭😭😭 badai ini mah  ...  South Kalimantan
# 8   @banjarbase bati² hujan lebat banar mati listr...  ...  South Kalimantan
# 9   sudah matlis, hujan daras sa angin" nya, kost ...  ...  South Kalimantan
# 10  01.23 waktu Banjarmasin, Banjir + hujan besert...  ...  South Kalimantan
# ...

# %%
#mendapatkan tweet wilayah palangkaraya
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-2.207460,113.916420,100km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space19 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space19.append([tweet.text, tweet.retweet_count])

spacedf19 = pd.DataFrame(data=space19, columns=['tweet','retweet_count'])
sdf19 = spacedf19.assign(City = 'Palangkaraya', Province = 'Central Kalimantan')
sdf19
# Out:
#                                                 tweet  ...            Province
# 0   Malam itu, saat anak dan istri om sudah tidur....  ...  Central Kalimantan
# 1   @jefrinichol Beruntung bgt mlm minggu dikotaku...  ...  Central Kalimantan
# 2   Orang zaman dulu hebat2 ya, dipenjara sekaligu...  ...  Central Kalimantan
# 3   Hujan deras disertai angin kencang di sejumlah...  ...  Central Kalimantan
# 4   Hujan deras disertai angin kencang melanda Des...  ...  Central Kalimantan
# 5   Aku bukannya tidak menyukai hujan, \nHanya tid...  ...  Central Kalimantan
# 6   Hujan deras dan disertai angin kencang sejak s...  ...  Central Kalimantan
# 7   @amanbrug 2. kipas angin\n3. tetangga panasin ...  ...  Central Kalimantan
# 8   Tentang malam sunyi suara katak kilatan petir ...  ...  Central Kalimantan
# 9   @missufe Kesel deh hari ini\nLagi jadi team li...  ...  Central Kalimantan
# 10  Hujan badai angin ribut halilintar duar dagum ...  ...  Central Kalimantan
# ...

# %%
#mendapatkan tweet wilayah tanjung selor
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "2.837679,117.363460,150km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space20 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space20.append([tweet.text, tweet.retweet_count])

spacedf20 = pd.DataFrame(data=space20, columns=['tweet','retweet_count'])
sdf20 = spacedf20.assign(City = 'Tanjung Selor', Province = 'North Kalimantan')
sdf20
# Out:
#                                                tweet  ...          Province
# 0      Hujan aja, jangan di sertai angin kencang :'(  ...  North Kalimantan
# 1  Hujan gini suhu AC kamar 16 + kipas angin nikm...  ...  North Kalimantan
# 2      @yournangel Hujan badai angin ribut halilitar  ...  North Kalimantan
#
# [3 rows x 4 columns]

# %%
kalimantan=pd.concat([sdf16,sdf17,sdf18,sdf19,sdf20]).reset_index(drop=True)
kalimantan.to_json('/content/kalimantan.json', orient='records')

# %%
#mendapatkan tweet wilayah denpasar
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-8.650000,115.216667,50km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space21 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space21.append([tweet.text, tweet.retweet_count])

spacedf21 = pd.DataFrame(data=space21, columns=['tweet','retweet_count'])
sdf21 = spacedf21.assign(City = 'Denpasar', Province = 'Bali')
sdf21
# Out:
#                                                 tweet  ...  Province
# 0   @kamalacempaka sudah balik dr SUB kemaren 😁......  ...      Bali
# 1   cuaca di wilayah banyuwangi malam ini umumnya ...  ...      Bali
# 2   cuaca di wilayah banyuwangi malam ini umumnya ...  ...      Bali
# 3   semangat trs para ojol yang lagi on pas ujan, ...  ...      Bali
# 4   Malam ini hujan sedang-lebat terjadi di Banyuw...  ...      Bali
# 5   Temenku kmren yg lagi ngezoom ulangan online, ...  ...      Bali
# 6   Hujan dan Angin Kencang, Atap Rumah Warga Peku...  ...      Bali
# 7   37 Pohon Tumbang di Karangasem Bali Akibat Huj...  ...      Bali
# 8   @TeameOfficial_ Hujan sih enggak, tapi angin n...  ...      Bali
# 9   Hujan reda terbitlah angin kencang. Bakalan se...  ...      Bali
# 10  @Bangsat_1999 Hujan angin badai cetar membahan...  ...      Bali
# 11  Angin dan hujan semoga tidak tidak terjadi apa...  ...      Bali
# 12  Padahal diluar hujan, tapi kipas angin tetep n...  ...      Bali
# ...

# %%
#mendapatkan tweet wilayah kupang
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-10.178757,123.597603,100km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space22 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space22.append([tweet.text, tweet.retweet_count])

spacedf22 = pd.DataFrame(data=space22, columns=['tweet','retweet_count'])
sdf22 = spacedf22.assign(City = 'Kupang', Province = 'East Nusa Tenggara')
sdf22
# Out:
#                                                tweet  ...            Province
# 0  yang terjadi pagi ini hujan angin di Labuan Ba...  ...  East Nusa Tenggara
#
# [1 rows x 4 columns]

# %%
#mendapatkan tweet wilayah mataram
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-8.583570,116.108063,100km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space23 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space23.append([tweet.text, tweet.retweet_count])

spacedf23 = pd.DataFrame(data=space23, columns=['tweet','retweet_count'])
sdf23 = spacedf23.assign(City = 'Mataram', Province = 'West Nusa Tenggara')
sdf23
# Out:
#                                                 tweet  ...            Province
# 0   Jangankan cobaan hujan badai angin ribut, pas ...  ...  West Nusa Tenggara
# 1   Musim hujan telah usai. Angin yang berhembus d...  ...  West Nusa Tenggara
# 2   @pln_123 situbondo selalu ya, gak ada hujan ga...  ...  West Nusa Tenggara
# 3   @dwihandaanda hujan badainya angin ribut halil...  ...  West Nusa Tenggara
# 4   @kamalacempaka sudah balik dr SUB kemaren 😁......  ...  West Nusa Tenggara
# ..                                                ...  ...                 ...
# 80  @na_dirs Posisi saya di Kab. Malang arah Lumaj...  ...  West Nusa Tenggara
# 81  akhirnya engkau kabulkan tuhan doaku tiap ming...  ...  West Nusa Tenggara
# 82  Kondisi terkini curah kobokan malam ini hujan ...  ...  West Nusa Tenggara
# 83  @dontplayplay__ @FiersaBesari Malang selatan d...  ...  West Nusa Tenggara
# 84    @igede_atm @weedeeblue Hujan pake angin ini Bli  ...  West Nusa Tenggara
#
# [85 rows x 4 columns]

# %%
balint=pd.concat([sdf21,sdf22,sdf23]).reset_index(drop=True)
balint.to_json('/content/balint.json', orient='records')

# %%
#mendapatkan tweet wilayah gorontalo
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "0.556174,123.058548,100km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space24 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space24.append([tweet.text, tweet.retweet_count])

spacedf24 = pd.DataFrame(data=space24, columns=['tweet','retweet_count'])
sdf24 = spacedf24.assign(City = 'Gorontalo', Province = 'Gorontalo')
sdf24
# Out:
#                                                tweet  ...   Province
# 0  mulanya siang jam 11\ndatanglah belanja syopi ...  ...  Gorontalo
# 1  Menanggapi laporan BMKG Maluku Utara terkait i...  ...  Gorontalo
# 2  Ya Allah, hamba suka hujan. tapi yang ga pake ...  ...  Gorontalo
#
# [3 rows x 4 columns]

# %%
#mendapatkan tweet wilayah mamuju
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-2.677840,118.887384,100km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space25 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space25.append([tweet.text, tweet.retweet_count])

spacedf25 = pd.DataFrame(data=space25, columns=['tweet','retweet_count'])
sdf25 = spacedf25.assign(City = 'Mamuju', Province = 'West Sulawesi')
sdf25
# Out:
#                                                 tweet  ...       Province
# 0   Dingin bnget🥶 ujan nya gk berenti² berrrr\nDis...  ...  West Sulawesi
# 1   Malam itu, saat anak dan istri om sudah tidur....  ...  West Sulawesi
# 2   @jefrinichol Beruntung bgt mlm minggu dikotaku...  ...  West Sulawesi
# 3   Orang zaman dulu hebat2 ya, dipenjara sekaligu...  ...  West Sulawesi
# 4   Hujan deras disertai angin kencang di sejumlah...  ...  West Sulawesi
# 5   Hujan deras disertai angin kencang melanda Des...  ...  West Sulawesi
# 6   Aku bukannya tidak menyukai hujan, \nHanya tid...  ...  West Sulawesi
# 7   Hujan deras dan disertai angin kencang sejak s...  ...  West Sulawesi
# 8   @amanbrug 2. kipas angin\n3. tetangga panasin ...  ...  West Sulawesi
# 9   Tentang malam sunyi suara katak kilatan petir ...  ...  West Sulawesi
# 10  @missufe Hai 🙋‍♀️ makji.di sini dingin hbs huj...  ...  West Sulawesi
# 11  @missufe Kesel deh hari ini\nLagi jadi team li...  ...  West Sulawesi
# ...

# %%
#mendapatkan tweet wilayah palu
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-0.898830,119.872559,200km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space26 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space26.append([tweet.text, tweet.retweet_count])

spacedf26 = pd.DataFrame(data=space26, columns=['tweet','retweet_count'])
sdf26 = spacedf26.assign(City = 'Palu', Province = 'Central Sulawesi')
sdf26
# Out:
#                                                 tweet  ...          Province
# 0   Malam itu, saat anak dan istri om sudah tidur....  ...  Central Sulawesi
# 1   @jefrinichol Beruntung bgt mlm minggu dikotaku...  ...  Central Sulawesi
# 2   Orang zaman dulu hebat2 ya, dipenjara sekaligu...  ...  Central Sulawesi
# 3   Hujan deras disertai angin kencang di sejumlah...  ...  Central Sulawesi
# 4   Hujan deras disertai angin kencang melanda Des...  ...  Central Sulawesi
# 5   Aku bukannya tidak menyukai hujan, \nHanya tid...  ...  Central Sulawesi
# 6   Hujan deras dan disertai angin kencang sejak s...  ...  Central Sulawesi
# 7   @amanbrug 2. kipas angin\n3. tetangga panasin ...  ...  Central Sulawesi
# 8   Tentang malam sunyi suara katak kilatan petir ...  ...  Central Sulawesi
# 9        angin kencang+hujan deras, mana masih diluar  ...  Central Sulawesi
# 10  @missufe Kesel deh hari ini\nLagi jadi team li...  ...  Central Sulawesi
# ...

# %%
#mendapatkan tweet wilayah Manado
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "	1.474830,124.842079,200km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space27 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space27.append([tweet.text, tweet.retweet_count])

spacedf27 = pd.DataFrame(data=space27, columns=['tweet','retweet_count'])
sdf27 = spacedf27.assign(City = 'Manado', Province = 'North Sulawesi')
sdf27
# Out:
#                                                tweet  ...        Province
# 0  mulanya siang jam 11\ndatanglah belanja syopi ...  ...  North Sulawesi
# 1  Manado hujan angin kencang beberapa hari ini.....  ...  North Sulawesi
# 2  Angin Barat meniup ombak di pesisir Manado. Sa...  ...  North Sulawesi
# 3  Angin,hujan,badai. Rusuh sekali. Persis kek ke...  ...  North Sulawesi
# 4  Menanggapi laporan BMKG Maluku Utara terkait i...  ...  North Sulawesi
# 5  Ya Allah, hamba suka hujan. tapi yang ga pake ...  ...  North Sulawesi
#
# [6 rows x 4 columns]

# %%
#mendapatkan tweet wilayah kendari
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-3.972201,122.514900,200km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space28 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space28.append([tweet.text, tweet.retweet_count])

spacedf28 = pd.DataFrame(data=space28, columns=['tweet','retweet_count'])
sdf28 = spacedf28.assign(City = 'Kendari', Province = 'South East Sulawesi')
sdf28
# Out:
#                                                 tweet  ...             Province
# 0   Info BMKG Minggu 12 Desember 2021, 7 Kabupaten...  ...  South East Sulawesi
# 1   New post (Wali Kota Parepare Pantau Sejumlah I...  ...  South East Sulawesi
# 2   Hujan disertai angin kencang berpotensi hingga...  ...  South East Sulawesi
# 3   @zwirasakti Pdhl waktu kecil biar mandi hujan ...  ...  South East Sulawesi
# 4   BMKG: Waspada potensi hujan lebat disertai ang...  ...  South East Sulawesi
# 5   Beberapa hari ini cuaca sedikit ekstrim, hujan...  ...  South East Sulawesi
# 6   haha hujan mi tamalanrea huhuu pake angin wush...  ...  South East Sulawesi
# 7   Hari ini hari ketiga, hujan disertai angin ken...  ...  South East Sulawesi
# 8   Pasca Hujan Deras dan Angin Kencang, Pemkot Pa...  ...  South East Sulawesi
# 9   New post (Pasca Hujan Deras dan Angin Kencang,...  ...  South East Sulawesi
# 10  @AlyRahmatiyah @katzedikke Apa ngga masuk angi...  ...  South East Sulawesi
# ...

# %%
#mendapatkan tweet wilayah makassar
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-5.135399,119.423790,100km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space29 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space29.append([tweet.text, tweet.retweet_count])

spacedf29 = pd.DataFrame(data=space29, columns=['tweet','retweet_count'])
sdf29 = spacedf29.assign(City = 'Makassar', Province = 'South Sulawesi')
sdf29
# Out:
#                                                 tweet  ...        Province
# 0   New post (Wali Kota Parepare Pantau Sejumlah I...  ...  South Sulawesi
# 1   Hujan disertai angin kencang berpotensi hingga...  ...  South Sulawesi
# 2   @zwirasakti Pdhl waktu kecil biar mandi hujan ...  ...  South Sulawesi
# 3   BMKG: Waspada potensi hujan lebat disertai ang...  ...  South Sulawesi
# 4   Beberapa hari ini cuaca sedikit ekstrim, hujan...  ...  South Sulawesi
# 5   haha hujan mi tamalanrea huhuu pake angin wush...  ...  South Sulawesi
# 6   Hari ini hari ketiga, hujan disertai angin ken...  ...  South Sulawesi
# 7   Pasca Hujan Deras dan Angin Kencang, Pemkot Pa...  ...  South Sulawesi
# 8   New post (Pasca Hujan Deras dan Angin Kencang,...  ...  South Sulawesi
# 9   @AlyRahmatiyah @katzedikke Apa ngga masuk angi...  ...  South Sulawesi
# 10  Kapolsek Palengaan Datangi TKP Rumah Roboh Aki...  ...  South Sulawesi
# ...

# %%
sulawesi=pd.concat([sdf24,sdf25,sdf26,sdf27,sdf28,sdf29]).reset_index(drop=True)
sulawesi.to_json('/content/sulawesi.json', orient='records')

# %%
#mendapatkan tweet wilayah ternate
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "0.785560,127.380830,100km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space30 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space30.append([tweet.text, tweet.retweet_count])

spacedf30 = pd.DataFrame(data=space30, columns=['tweet','retweet_count'])
sdf30 = spacedf30.assign(City = 'Ternate', Province = 'North Maluku')
sdf30
# Out:
#                                                tweet  ...      Province
# 0  mulanya siang jam 11\ndatanglah belanja syopi ...  ...  North Maluku
# 1  Manado hujan angin kencang beberapa hari ini.....  ...  North Maluku
# 2  Angin Barat meniup ombak di pesisir Manado. Sa...  ...  North Maluku
# 3  Angin,hujan,badai. Rusuh sekali. Persis kek ke...  ...  North Maluku
# 4  Menanggapi laporan BMKG Maluku Utara terkait i...  ...  North Maluku
# 5  Ya Allah, hamba suka hujan. tapi yang ga pake ...  ...  North Maluku
#
# [6 rows x 4 columns]

# %%
#mendapatkan tweet wilayah ambon
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-3.654703,128.190643,150km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space31 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space31.append([tweet.text, tweet.retweet_count])

spacedf31 = pd.DataFrame(data=space31, columns=['tweet','retweet_count'])
sdf31 = spacedf31.assign(City = 'Ambon', Province = 'Maluku')
sdf31
# Out:
#                                                tweet  ...  Province
# 0  Info BMKG Minggu 12 Desember 2021, 7 Kabupaten...  ...    Maluku
# 1        Hujan deras + angin https://t.co/tdYy030vHD  ...    Maluku
#
# [2 rows x 4 columns]

# %%
#mendapatkan tweet wilayah manokwari
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-0.861453,134.062042,150km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space32 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space32.append([tweet.text, tweet.retweet_count])

spacedf32 = pd.DataFrame(data=space32, columns=['tweet','retweet_count'])
sdf32 = spacedf32.assign(City = 'Manokwari', Province = 'West Papua')
sdf32
# Out:
#                                                tweet  ...    Province
# 0  Mohon @infoBMKG menginformasikan juga prakiraa...  ...  West Papua
# 1  Wow ..\nHujan Keras disertai Angin Kencang..\n...  ...  West Papua
# 2  @pln_123 @ayudwih @pln_123 cape banget mention...  ...  West Papua
# 3  @pln_123 cape banget mention ngeluh karena mat...  ...  West Papua
# 4  @pln_123 cape banget mention ngeluh karena mat...  ...  West Papua
# 5  yo.. cuaca kemarin terjadi lagi hari ini.. lan...  ...  West Papua
#
# [6 rows x 4 columns]

# %%
#mendapatkan tweet wilayah Jayapura
auth = tweepy.auth.OAuthHandler(Ck, Cs)
auth.set_access_token(At, As)
api = tweepy.API(auth)

Geo, N = "-2.539637,140.702130,250km", 200  # HAti-hati jangan ada spasi di Lat-Lon-Radius
qry = 'hujan angin'
space33 = []
for tweet in tweepy.Cursor(api.search, q=qry, count=100, geocode=Geo).items(N):
    space33.append([tweet.text, tweet.retweet_count])

spacedf33 = pd.DataFrame(data=space33, columns=['tweet','retweet_count'])
sdf33 = spacedf33.assign(City = 'Jayapura', Province = 'Papua')
sdf33
# Out:
#                                                tweet  ...  Province
# 0  Suka bingung sama manusia yang gada angin gada...  ...     Papua
# 1  @BucinOfTheYears Disini baru angin kencang dan...  ...     Papua
# 2  sabar ya cantik, jaga lilin nya baik2 jangan s...  ...     Papua
#
# [3 rows x 4 columns]

# %%
malukupapua=pd.concat([sdf30,sdf31,sdf32,sdf33]).reset_index(drop=True)
malukupapua.to_json('/content/malukupapua.json', orient='records')
